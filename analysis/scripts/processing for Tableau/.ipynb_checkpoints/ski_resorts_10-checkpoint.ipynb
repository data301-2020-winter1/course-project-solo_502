# %%
import pandas as pd
import numpy as np

df_BS = pd.read_csv(r'C:\Users\Len\Documents\GitHub\solo_502\course-project-solo_502\data\processed\Big_Sky_months.csv')
df_BS_raw = pd.read_csv(r'C:\Users\Len\Documents\GitHub\solo_502\course-project-solo_502\data\raw\Big_Sky.csv')
df_BS = df_BS.assign(latitude = df_BS_raw.loc[0,'lat'])
df_BS = df_BS.assign(longitude = df_BS_raw.loc[0,'long'])
df_BS = df_BS.assign(Resort = 'Big Sky')

df_BW = pd.read_csv(r'C:\Users\Len\Documents\GitHub\solo_502\course-project-solo_502\data\processed\Big_White_months.csv')
df_BW_raw = pd.read_csv(r'C:\Users\Len\Documents\GitHub\solo_502\course-project-solo_502\data\raw\Big_White.csv')
df_BW = df_BW.assign(latitude = df_BW_raw.loc[0,'lat'])
df_BW = df_BW.assign(longitude = df_BW_raw.loc[0,'long'])
df_BW = df_BW.assign(Resort = 'Big White')

df_JH = pd.read_csv(r'C:\Users\Len\Documents\GitHub\solo_502\course-project-solo_502\data\processed\Jackson_months.csv')
df_JH_raw = pd.read_csv(r'C:\Users\Len\Documents\GitHub\solo_502\course-project-solo_502\data\raw\Jackson_Hole.csv')
df_JH = df_JH.assign(latitude = df_JH_raw.loc[0,'lat'])
df_JH = df_JH.assign(longitude = df_JH_raw.loc[0,'long'])
df_JH = df_JH.assign(Resort = 'Jackson Hole')

df_LL = pd.read_csv(r'C:\Users\Len\Documents\GitHub\solo_502\course-project-solo_502\data\processed\Lake_Louise_months.csv')
df_LL_raw = pd.read_csv(r'C:\Users\Len\Documents\GitHub\solo_502\course-project-solo_502\data\raw\Lake_Louise.csv')
df_LL = df_LL.assign(latitude = df_LL_raw.loc[0,'lat'])
df_LL = df_LL.assign(longitude = df_LL_raw.loc[0,'long'])
df_LL = df_LL.assign(Resort = 'Lake Louise')

df_MM = pd.read_csv(r'C:\Users\Len\Documents\GitHub\solo_502\course-project-solo_502\data\processed\Mammoth_months.csv')
df_MM_raw = pd.read_csv(r'C:\Users\Len\Documents\GitHub\solo_502\course-project-solo_502\data\raw\Mammoth_Mountain.csv')
df_MM = df_MM.assign(latitude = df_MM_raw.loc[0,'lat'])
df_MM = df_MM.assign(longitude = df_MM_raw.loc[0,'long'])
df_MM = df_MM.assign(Resort = 'Mammoth Mountain')

df_MB = pd.read_csv(r'C:\Users\Len\Documents\GitHub\solo_502\course-project-solo_502\data\processed\Mt_Baker_months.csv')
df_MB_raw = pd.read_csv(r'C:\Users\Len\Documents\GitHub\solo_502\course-project-solo_502\data\raw\Mount_Baker.csv')
df_MB = df_MB.assign(latitude = df_MB_raw.loc[0,'lat'])
df_MB = df_MB.assign(longitude = df_MB_raw.loc[0,'long'])
df_MB = df_MB.assign(Resort = 'Mount Baker')

df_MW = pd.read_csv(r'C:\Users\Len\Documents\GitHub\solo_502\course-project-solo_502\data\processed\Mt_Washington_months.csv')
df_MW_raw = pd.read_csv(r'C:\Users\Len\Documents\GitHub\solo_502\course-project-solo_502\data\raw\Mt_Washington.csv')
df_MW = df_MW.assign(latitude = df_MW_raw.loc[0,'lat'])
df_MW = df_MW.assign(longitude = df_MW_raw.loc[0,'long'])
df_MW = df_MW.assign(Resort = 'Mount Washington')

df_MH = pd.read_csv(r'C:\Users\Len\Documents\GitHub\solo_502\course-project-solo_502\data\processed\MtHood_months.csv')
df_MH_raw = pd.read_csv(r'C:\Users\Len\Documents\GitHub\solo_502\course-project-solo_502\data\raw\Mount_Hood.csv')
df_MH = df_MH.assign(latitude = df_MH_raw.loc[0,'lat'])
df_MH = df_MH.assign(longitude = df_MH_raw.loc[0,'long'])
df_MH = df_MH.assign(Resort = 'Mount Hood')

df_VA = pd.read_csv(r'C:\Users\Len\Documents\GitHub\solo_502\course-project-solo_502\data\processed\Vail_months.csv')
df_VA_raw = pd.read_csv(r'C:\Users\Len\Documents\GitHub\solo_502\course-project-solo_502\data\raw\Vail.csv')
df_VA = df_VA.assign(latitude = df_VA_raw.loc[0,'lat'])
df_VA = df_VA.assign(longitude = df_VA_raw.loc[0,'long'])
df_VA = df_VA.assign(Resort = 'Vail')

df_WH = pd.read_csv(r'C:\Users\Len\Documents\GitHub\solo_502\course-project-solo_502\data\processed\Whistler_months.csv')
df_WH_raw = pd.read_csv(r'C:\Users\Len\Documents\GitHub\solo_502\course-project-solo_502\data\raw\Whistler.csv')
df_WH = df_WH.assign(latitude = df_WH_raw.loc[0,'lat'])
df_WH = df_WH.assign(longitude = df_WH_raw.loc[0,'long'])
df_WH = df_WH.assign(Resort = 'Whistler')

dataframes = [df_BS, df_BW, df_JH, df_LL, df_MM, df_MB, df_MW, df_MH, df_VA, df_WH]
resorts = pd.concat(dataframes)
resorts = resorts.assign(Year_month = resorts.Year.astype(str) + ' ' + resorts.Month.astype(str))
ski_resorts_10 = resorts.reset_index()
ski_resorts_10.to_csv(r'C:\Users\Len\Documents\GitHub\solo_502\course-project-solo_502\data\processed\ski_resorts_10.csv', index=False)

# %%
months = ['May', 'Jun', 'Jul', 'Aug', 'Sept', 'Oct']

ski_resorts_w = (ski_resorts_10
                      .loc[lambda row : ~row['Month'].str.contains('May')]
                      .loc[lambda row : ~row['Month'].str.contains('Jun')]
                      .loc[lambda row : ~row['Month'].str.contains('Jul')]
                      .loc[lambda row : ~row['Month'].str.contains('Aug')]
                      .loc[lambda row : ~row['Month'].str.contains('Sep')]
                      .loc[lambda row : ~row['Month'].str.contains('Oct')]
                     )
ski_resorts_winter = (
    ski_resorts_w
    .reset_index()
    .drop(columns=['index', 'level_0'])
)

ski_resorts_winter
# Out:
#      Month  Year  Max Temp  Min Temp  Ave Temp  Precipitation  Radiation  \
# 0      Jan  1901      -4.5     -12.1      -8.3             85    -9999.0
# 1      Feb  1901      -5.6     -14.4     -10.0             94    -9999.0
# 2      Mar  1901      -1.6      -9.9      -5.8            107    -9999.0
# 3      Apr  1901       3.3      -6.7      -1.7            164    -9999.0
# 4      Nov  1901       3.0      -5.6      -1.3             61    -9999.0
# ...    ...   ...       ...       ...       ...            ...        ...
# 7135   Feb  2019      -4.5      -9.4      -7.0             24    -9999.0
# 7136   Mar  2019       3.8      -4.5      -0.3              0    -9999.0
# 7137   Apr  2019       4.7      -2.1       1.3             92    -9999.0
# 7138   Nov  2019       3.5      -2.4       0.6             88    -9999.0
# 7139   Dec  2019      -0.2      -4.6      -2.4            185    -9999.0
#
#       DDays < 0°C  DDays > 5°C  DDays < 18°C  DDays > 18°C  Frost Free Days  \
# ...
