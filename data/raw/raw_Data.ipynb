# %%
import pandas as pd

print(pd.read_csv("ClimateData_UBCO.csv"))
print(pd.read_csv("ClimateData_UBCO_forecast.csv"))
print(pd.read_csv("ClimateData_Big_White.csv"))
print(pd.read_csv("ClimateData_Big_White_forecast.csv"))
# Out:
#         Lat     long   elev     period  MAT   MWMT   MCMT    TD   MAP   MSP   \
# 0    49.939 -119.396    446  year_1901   8.7   21.3   -3.8  25.1   293   139
# 1    49.939 -119.396    446  year_1902   8.0   18.4   -3.0  21.4   386   194
# 2    49.939 -119.396    446  year_1903   7.5   18.3   -2.1  20.4   399   248
# 3    49.939 -119.396    446  year_1904   8.6   19.9   -2.1  22.0   297    86
# 4    49.939 -119.396    446  year_1905   8.3   20.7   -2.1  22.8   300   176
# ..      ...      ...    ...        ...   ...    ...    ...   ...   ...   ...
# 114  49.939 -119.396    446  year_2015  10.9   22.5    0.0  22.5   332   120
# 115  49.939 -119.396    446  year_2016  10.4   21.5   -4.3  25.8   410   175
# 116  49.939 -119.396    446  year_2017   9.4   23.1   -4.0  27.1   365    99
# 117  49.939 -119.396    446  year_2018   9.6   22.1    0.7  21.4   451   152
# 118  49.939 -119.396    446  year_2019   8.9   20.9    0.2  20.6   353   195
#
# ...
